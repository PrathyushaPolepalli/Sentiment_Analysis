# %%
#Dependencies
import tweepy
import csv
import numpy as np
from textblob import TextBlob

# %%
#Keys
consumer_key='0nQH1qOhLF81PErJGiZsJqxrS'
consumer_secret='FcXf4DLyI2YtrcxOxlfHFafJfe68p8i0rAZmOonstgSrVC0BH9'
access_token='752158756486520832-mqGIrJNuAssjs8YC3Ax8hbVS33Crnuy'
access_token_secret='pjTJPVr9IWKNl1e1fT0sA7CSenvoPiRP3MX2VTfFVgJNr'

# %%
#Authentication
auth=tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
#Acessing Twitter's API
api=tweepy.API(auth)

# %%
#Searching Tweets with keyword
public_tweets=api.search(q='Big bang theory', count=100)

# %%
#Sentiment analysis of tweets
#Polarity measures how positive or negative the text is
#Subjectivity measures how much of an opinion or factual it is
for tweet in public_tweets:
    print(tweet.text)
    analysis=TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# Wow, @ProSieben bringt „The Big Bang Theory“ ab der ersten Folge 😳
# Sentiment(polarity=0.05, subjectivity=0.55)
# "I bet you watch that Big Bang Theory program, that Sheldon is something else" someone please help me
# Sentiment(polarity=0.0, subjectivity=0.1)
# Retail therapy when you’re living with a #chronicillness is going out and getting steroids and new jammies (but the… https://t.co/7i4D3CQo2q
# Sentiment(polarity=0.13636363636363635, subjectivity=0.45454545454545453)
# After 14 hours of The Big Bang Theory, McFuckface appears to be fine. Perhaps he just has exceptionally poor taste… https://t.co/EBfZh7v89t
# Sentiment(polarity=0.005555555555555554, subjectivity=0.39999999999999997)
# I would like to call this outfit : The Big Bang Theory. The solar system and dinosaurs totally go together this is… https://t.co/W1utJfsNOR
# Sentiment(polarity=0.0, subjectivity=0.425)
# @innuovo @albertoplaza Ese si es un buen chiste, tipo The Big Bang Theory
# ...

# %%
#To find if sentiment is positive or Negative
def get_label(analysis, threshold = 0):
    if analysis.sentiment[0]>threshold:
        return 'Positive'
    else:
        return 'Negative'
#Retrieve Tweets and Save them in csv file
this_polarities = []
with open('tweets.csv', 'w') as this_file:
    this_file.write('tweet,sentiment_label\n')
    for tweet in public_tweets:
        analysis = TextBlob(tweet.text)
        this_polarities.append(analysis.sentiment[0])
        this_file.write('%s,%s\n' % (tweet.text.encode('utf8'), get_label(analysis)))
print(np.mean(this_polarities))
# Out:
# 0.05583444741532977

# %%
with open("tweets.csv") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['tweet', 'sentiment_label']
# ["b'Wow", " @ProSieben bringt \\xe2\\x80\\x9eThe Big Bang Theory\\xe2\\x80\\x9c ab der ersten Folge \\xf0\\x9f\\x98\\xb3'", 'Positive']
# ['b\'"I bet you watch that Big Bang Theory program', ' that Sheldon is something else" someone please help me\'', 'Negative']
# ["b'Retail therapy when you\\xe2\\x80\\x99re living with a #chronicillness is going out and getting steroids and new jammies (but the\\xe2\\x80\\xa6 https://t.co/7i4D3CQo2q'", 'Positive']
# ["b'After 14 hours of The Big Bang Theory", " McFuckface appears to be fine. Perhaps he just has exceptionally poor taste\\xe2\\x80\\xa6 https://t.co/EBfZh7v89t'", 'Positive']
# ["b'I would like to call this outfit : The Big Bang Theory. The solar system and dinosaurs totally go together this is\\xe2\\x80\\xa6 https://t.co/W1utJfsNOR'", 'Negative']
# ["b'@innuovo @albertoplaza Ese si es un buen chiste", " tipo The Big Bang Theory'", 'Negative']
# ...
